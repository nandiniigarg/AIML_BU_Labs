# %%
## E20CSE093
## SAMRIDDH SRIVASTAVA
## LAB ASSIGNMENT-2.1

# %%
## Part A

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv("Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df['Species'].value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Name: Species, dtype: int64

# %%
## Part B

# %%
species=df['Species'].value_counts()
print(species.index)
print(species.values)
plt.bar(x=species.index,height=species.values,color=['blue','green','red'])
# Out:
# Index(['Iris-virginica', 'Iris-versicolor', 'Iris-setosa'], dtype='object')
# [50 50 50]
# <BarContainer object of 3 artists>

# %%
plt.plot(df.Id,df["SepalLengthCm"],linestyle="dashed")

# %%
x=df['SepalLengthCm']
y=np.sin(x)
z=np.cos(x)
plt.plot(x,y,x,z)
plt.xlabel('x values from 0 to 4pi')
plt.ylabel('sin(x) and cos(x)')
plt.title('Plot of sin and cos from 0 to 4pi')
plt.legend(['sin(x)','cos(x)'])
plt.show()

# %%
plt.hist(df['SepalLengthCm'])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <a list of 10 Patch objects>)

# %%
plt.pie(species)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e86a8b1580>,
# ...
#  [Text(0.5499999702695115, 0.9526279613277875, ''),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, ''),
#   Text(0.5500001486524352, -0.9526278583383436, '')])

# %%
plt.pie(df['SepalLengthCm'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1e86a8ef790>,
# ...
#  [Text(1.0998162248289156, 0.020106506486022895, ''),
#   Text(1.0983893303845753, 0.059505284616782936, ''),
#   Text(1.0956920682406373, 0.0972568331509659, ''),
#   Text(1.091842090596001, 0.1337192925607762, ''),
#   Text(1.0865955946241563, 0.17120167564418406, ''),
#   Text(1.0794604973247504, 0.21157749104146875, ''),
#   Text(1.0711853524326178, 0.25012385078958144, ''),
#   Text(1.061946535861541, 0.2868266984987159, ''),
#   Text(1.051681945368862, 0.322436173195822, ''),
#   Text(1.0403517900227819, 0.35730680513585744, ''),
#   Text(1.0264549462634536, 0.39546206302411735, ''),
#   Text(1.0113144459682202, 0.4327159476792971, ''),
#   Text(0.9958295372217366, 0.4672510383046166, ''),
#   Text(0.9800624176136543, 0.4994773844542706, ''),
#   Text(0.9613427184591771, 0.5346215274991454, ''),
#   Text(0.9384959352390051, 0.5737816479636354, ''),
#   Text(0.9149313166628202, 0.6106559471499793, ''),
# ...

# %% [markdown]
# ## Part C

# %%
sb.scatterplot(x=df["SepalLengthCm"],y=df["SepalWidthCm"])

# %%
sb.scatterplot(x=df["SepalLengthCm"],y=df["SepalWidthCm"],hue=df["Species"])

# %%
sb.violinplot(x=df["SepalWidthCm"])
plt.xlabel("Sepal Width")
# Out:
# Text(0.5, 0, 'Sepal Width')

# %%
sb.pairplot(df)

# %%
corr=df.corr()
corr
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
sb.heatmap(corr)
